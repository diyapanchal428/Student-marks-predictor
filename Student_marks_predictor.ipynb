# %% [markdown]
# <a href="https://colab.research.google.com/github/diyapanchal428/Student-marks-predictor/blob/main/Student_marks_predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression


data = {
    "hours": [1, 2, 3, 4, 5],
    "marks": [30, 40, 50, 60, 70]
}
df = pd.DataFrame(data)

X = df[["hours"]]
y = df["marks"]

model = LinearRegression()
model.fit(X, y)

# ample: 6 ghante padhne par kitne marks?)
prediction = model.predict([[6]])
print(f"Predicted Marks for 6 hours of study: {prediction[0]}")
# Out:
# Predicted Marks for 6 hours of study: 80.0
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
